# %% [markdown]
# <a href="https://colab.research.google.com/github/Eshwar1435/AI-ML_2303A52072/blob/main/lab_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Part 1 Implement Basic Data Structures using Numpy, Pandas
#  1. Lists
#  2. Arrays
#  3. Identify their type using type()
#  4. Perform mathematical operations on these datasets created- multiplication, division,
#  powero
#  5. Combine text with Numpy fuction to generate a textual output- Addition of Two:
#  array1 +array 2
#  6. Implement np.sin(), log(), log2(), np.exp()

# %%
import numpy as np
list1=[3,5,8,4]

arr1=np.array(list1)
arr1
# Out:
# array([3, 5, 8, 4])

# %%
type(list1)
# Out:
# list

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
list2=[1,6,3,9]

arr2=np.array(list2)
arr2
# Out:
# array([1, 6, 3, 9])

# %%
print("multiplication of arr1 & arr2 : ",arr1*arr2)
print("division of arr1 & arr2 : ",arr1/arr2)
print("poweroff of arr1 & arr2 : ",arr1**arr2)
# Out:
# multiplication of arr1 & arr2 :  [ 3 30 24 36]
# division of arr1 & arr2 :  [3.         0.83333333 2.66666667 0.44444444]
# poweroff of arr1 & arr2 :  [     3  15625    512 262144]

# %%
print("Addition of Two arrays :", arr1 +arr2)
# Out:
# Addition of Two arrays : [ 4 11 11 13]

# %%
print(np.sin(arr1))
# Out:
# [ 0.14112001 -0.95892427  0.98935825 -0.7568025 ]

# %%
np.log(arr1)
# Out:
# array([1.09861229, 1.60943791, 2.07944154, 1.38629436])

# %%
np.log2(arr1)
# Out:
# array([1.5849625 , 2.32192809, 3.        , 2.        ])

# %%
np.exp(arr1)
# Out:
# array([  20.08553692,  148.4131591 , 2980.95798704,   54.59815003])

# %% [markdown]
# Part 2 Visualization of Data using matplotlib, pyplots Pack
# ages[CO2]
#  1. Generate a Data set for Health Care using the following:
#  people = [kiran, arun, vijay, varun]
#  age =[25, 30, 35, 40, 45]
#  height =[145, 151, 165, 173]
#  weight=[45, 55, 65, 75]
#  2. Using the generated dataset given above. Generate the following graphs and justify the
#  relationships among the vectors.
#  3. Scatter Plot
#  4. Bar Chart
#  5. Histogram
#  6. Provide Graph Title, labels for X, Y axis with proper justi cation and explanation of
#  the graph

# %%
import matplotlib.pyplot as plt
people = ['Ann','Brandon','Chen','David','Emily','Farook',
          'Gagan','Hamish','Imran','Julio','Katherine','Lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]
plt.scatter(weight,height)
plt.title('Relationship between weigth and height of patient')
plt.xlabel('weight')
plt.ylabel('height')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')
#main plot function 'bar
plt.bar(x=people,height=weight,width=0.6,color='green',edgecolor='black',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='orange',edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Part 3 Access Data from Various Data Sources using builtin Func
# tion of Numpy, Pandas[CO3]
#  1. Generate your own dataset using MS Excel and Notepad to prepare the dataset. Save
#  it in Google Drive and access it in Google Colab.
#  2. Upload the text le using tab seperated value(.tsv) and access the data from the le.
#  3. Upload the text le using comma seperated value(.csv) and access the data from le.
#  4. Access the excel le using .xlsx
#  5. Access the text from the URL

# %%
import pandas as pd
df1=pd.read_table("/content/olmpics_medals.txt")
df1
# Out:
#                   Year,City,Sport,Event,Medal,Athlete
# 0   2000,Sydney,Athletics,Men's 400m Hurdles,Bronz...
# 1   2000,Sydney,Tennis,Men's Singles,Gold,Leander ...
# 2   2004,Athens,Shooting,Men's 10m Air Rifle,Silve...
# 3   2004,Athens,Boxing,Men's Light Flyweight,Bronz...
# 4   2008,Beijing,Boxing,Men's Light Flyweight,Bron...
# 5   2008,Beijing,Shooting,Men's 10m Air Rifle,Gold...
# 6   2012,London,Shooting,Men's 10m Air Rifle,Silve...
# 7   2012,London,Boxing,Women's Flyweight,Bronze,Ma...
# 8   2016,Rio de Janeiro,Badminton,Women's Singles,...
# 9   2016,Rio de Janeiro,Wrestling,Women's Freestyl...
# 10  2020,Tokyo,Weightlifting,Women's 49kg,Silver,M...
# 11  2020,Tokyo,Badminton,Women's Singles,Bronze,PV...
# 12  2020,Tokyo,Hockey,Men's Team,Bronze,Indian Men...
# 13  2020,Tokyo,Athletics,Men's Javelin Throw,Gold,...

# %%
df2=pd.read_csv("/content/india_olympic_medals.csv")
df2
# Out:
#     Year            City          Sport                   Event   Medal  \
# 0   2000          Sydney      Athletics      Men's 400m Hurdles  Bronze
# 1   2000          Sydney         Tennis           Men's Singles    Gold
# 2   2004          Athens       Shooting     Men's 10m Air Rifle  Silver
# 3   2004          Athens         Boxing   Men's Light Flyweight  Bronze
# 4   2008         Beijing         Boxing   Men's Light Flyweight  Bronze
# 5   2008         Beijing       Shooting     Men's 10m Air Rifle    Gold
# 6   2012          London       Shooting     Men's 10m Air Rifle  Silver
# 7   2012          London         Boxing       Women's Flyweight  Bronze
# 8   2016  Rio de Janeiro      Badminton         Women's Singles  Silver
# 9   2016  Rio de Janeiro      Wrestling  Women's Freestyle 58kg  Bronze
# 10  2020           Tokyo  Weightlifting            Women's 49kg  Silver
# 11  2020           Tokyo      Badminton         Women's Singles  Bronze
# 12  2020           Tokyo         Hockey              Men's Team  Bronze
# 13  2020           Tokyo      Athletics     Men's Javelin Throw    Gold
#
#                      Athlete
# 0                    PT Usha
# 1               Leander Paes
# 2             Abhinav Bindra
# 3             Vijender Singh
# 4             Vijender Singh
# 5             Abhinav Bindra
# 6                Vijay Kumar
# 7                   Mary Kom
# 8                  PV Sindhu
# 9               Sakshi Malik
# 10             Mirabai Chanu
# 11                 PV Sindhu
# 12  Indian Men's Hockey Team
# 13             Neeraj Chopra

# %%
df3=pd.read_excel("/content/india_olympic_medals.xlsx")
df3
# Out:
#     Year            City          Sport                   Event   Medal  \
# 0   2000          Sydney      Athletics      Men's 400m Hurdles  Bronze
# 1   2000          Sydney         Tennis           Men's Singles    Gold
# 2   2004          Athens       Shooting     Men's 10m Air Rifle  Silver
# 3   2004          Athens         Boxing   Men's Light Flyweight  Bronze
# 4   2008         Beijing         Boxing   Men's Light Flyweight  Bronze
# 5   2008         Beijing       Shooting     Men's 10m Air Rifle    Gold
# 6   2012          London       Shooting     Men's 10m Air Rifle  Silver
# 7   2012          London         Boxing       Women's Flyweight  Bronze
# 8   2016  Rio de Janeiro      Badminton         Women's Singles  Silver
# 9   2016  Rio de Janeiro      Wrestling  Women's Freestyle 58kg  Bronze
# 10  2020           Tokyo  Weightlifting            Women's 49kg  Silver
# 11  2020           Tokyo      Badminton         Women's Singles  Bronze
# 12  2020           Tokyo         Hockey              Men's Team  Bronze
# 13  2020           Tokyo      Athletics     Men's Javelin Throw    Gold
#
#                      Athlete
# 0                    PT Usha
# 1               Leander Paes
# 2             Abhinav Bindra
# 3             Vijender Singh
# 4             Vijender Singh
# 5             Abhinav Bindra
# 6                Vijay Kumar
# 7                   Mary Kom
# 8                  PV Sindhu
# 9               Sakshi Malik
# 10             Mirabai Chanu
# 11                 PV Sindhu
# 12  Indian Men's Hockey Team
# 13             Neeraj Chopra
